# %% [markdown]
# # Create EndNote Import of References
#
# This code will processes a directory of pdf files and creates a bibliography reference file for import into EndNote 21
#
# * __EndNote Import Instructions__
#     * 1. Given the Output file of this run "<some_name>.nbib"
#     * 2. Open EndNote21
#             * File->Import… (Select File)
#     * 3. If prompted,
#             * _Choose a Filter_
#             * Select filter: __BibTex__
#     * 4. The References should now be in your EndNote Library
#
#
# * Before running this notebook On Watson
#     * Start grobid server to get references
#         * `cd Code/Java/grobid`
#         * `/gradlew run`
#         * Note: When starting the service will never reach 100% but it will still be running!
#     * Start NGINX danhiggins.org to lookup pdfs
#         * `cd /var/www/danhiggins.org/data`
#         * copy any need pdf files into this directory
#         * NGINX is not used to create the reference but if running the pdfs will be available for lookup from endnote notes in the reference

# %%
import requests
import json
import re
from urllib.parse import quote

def process_header(file_path):
    """
    Using the pdf content use AI to find the bibliography reference data
    See: https://grobid.readthedocs.io/en/latest/
    """
    url = 'http://192.168.1.101:8070/api/processHeaderDocument'
    headers = {
        'Accept': 'application/x-bibtex'
    }
    files = {
        'input': open(file_path, 'rb')
    }

    response = requests.post(url, headers=headers, files=files)

    if response.status_code == 200:
        return response.text
    else:
        print("Failed to upload file")
        print("Status code:", response.status_code)
        return ""
        


def bibtex_to_json(bibtex_str, paper_url):
    """Convert the bibliography text from grobid  into a dictionary

    Args:
        bibtex_str (str): bibliography text from grobid
        paper_url (str): pdf file name

    Raises:
        ValueError: If the Input text can not be parsed

    Returns:
        dict: The bibliography text as a dictionary
    """
    try:
        # Remove the @misc{ and } at the start and end
        if not bibtex_str.startswith('@misc{'):
            raise ValueError("Input does not start with '@misc{'")
        bibtex_str = bibtex_str.strip()[6:].strip()
        if not bibtex_str.endswith('}'):
            raise ValueError("Input does not end with '}'")
        bibtex_str = bibtex_str[:-1].strip()

        # Split the key and the fields
        try:
            key, fields_str = bibtex_str.split(',', 1)
        except ValueError:
            raise ValueError("Input does not contain a valid key and fields")

        # Extract fields
        fields = re.findall(r'\s*(\w+)\s*=\s*{(.*?)}\s*(?:,|$)', fields_str, re.DOTALL)

        if not fields:
            raise ValueError("No valid fields found in input")

        # Convert to dictionary
        encoded_paper_url = quote(paper_url)
        bibtex_dict = {"type": "misc", "key": key.strip(), "pdf_url":f"https://danhiggins.org/data/{encoded_paper_url}"}
        for field in fields:
            field_name = field[0].strip()
            field_value = field[1].strip().replace('\n', ' ')
            bibtex_dict[field_name] = field_value

        return bibtex_dict
    except Exception as e:
        return {"error": str(e)}

# %%
from habanero import Crossref

def cross_ref(doi):
    """Look up the bibliography given that you have a doi reference
    Note: Crossref provides additional information not available from grobid
    but not all bibliographies have a doi reference

    Args:
        doi (URL): doi URL to a document

    Returns:
        dict: The bibliography text as a dictionary
    """
    citation = {}
    chars_to_remove = "(){}[]"
    # Create a translation table that maps each chars_to_remove to None
    translation_table = str.maketrans('', '', chars_to_remove)

    # Remove the special characters from the input
    doi = doi.translate(translation_table)

    cr = Crossref()
    try:
        metadata = cr.works(ids=doi)
        # Extract citation information
        citation['title'] = metadata['message']['title'][0]
        authors_lst = [author.get('given','') + " " + author.get('family','') for author in metadata['message'].get('author','')]
        citation['authors'] = ' and '.join(authors_lst)
        container_title = metadata['message'].get('container-title',[])
        if container_title:
            citation['journal'] = container_title[0]
        citation['year'] = metadata['message']['created']['date-parts'][0][0]
        citation['volume'] = metadata['message'].get('volume', 'N/A')
        citation['issue'] = metadata['message'].get('issue', 'N/A')
        citation['page'] = metadata['message'].get('page', 'N/A')
    except Exception as e:
        print("Failed to process:", e)
    
    return citation
    # Format the citation

# Define the DOI
doi = "10.1534/genetics.117.300106" # Right
print(json.dumps(cross_ref(doi),indent=4))
# Out:
# {
#     "title": "Lipid and Carbohydrate Metabolism in Caenorhabditis elegans",
#     "authors": "",
#     "journal": "Genetics",
#     "year": 2023,
#     "volume": "N/A",
#     "issue": "N/A",
#     "page": "N/A"
# }

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def similarity_score(str1, str2):
    """Given two string return a score between 0 and 1 the represents how similar the strings are to eachother 
    NOTE: In this code similarity_score is used to compare the likeness of two titles  
    """
    documents = [str1, str2]

    # Convert the strings to vectors
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(documents)

    # Compute cosine similarity
    cosine_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])
    return cosine_sim[0][0]


str1 = "I love programming"
str2 = "Programming is my passion"
score = similarity_score(str1,str2)
print(f"Cosine similarity: {score}")
# Out:
# Cosine similarity: 0.22028815056182974

# %%
def create_nbib(papers, out_file):
    """Give a List of papers convert to a format that can be imported into endnote

    Args:
        papers (list): A list of dictionaries representing articles
        out_file (str): the endnote import file name
    """
    bib_lex_lib=""
    for article in papers:
        bib_lex = (
            f"@Article{{\n"
            f"author ={{{article.get('author', '')}}},\n"
            f"title ={{{article.get('title', '')}}},\n"
            f"year ={{{article.get('year', '')}}},\n"
            f"doi ={{{article.get('doi', '')}}},\n"
            f"abstract ={{{article.get('abstract', '')}}},\n"
            f"keywords ={{{article.get('keywords', '')}}},\n"
            f"note ={{{article.get('pdf_url', '')}}},\n"
            f"journal ={{{article.get('journal', '')}}},\n"
            f"volume ={{{article.get('volume', '')}}},\n"
            f"pages ={{{article.get('pages', '')}}}\n"
            f"}}\n\n"
        )
        bib_lex_lib += bib_lex
    
    with open(out_file, 'w') as file:
        file.write(bib_lex_lib)

# %%
import os

def process_pdfs_in_directory(directory_path):
    papers = []
    # Check if the directory exists
    if not os.path.isdir(directory_path):
        print(f"The directory {directory_path} does not exist.")
        return

    # List all files in the directory
    processed = 0
    file_list = os.listdir(directory_path)
    num_files = len(file_list)
    for filename in file_list:
        # Construct the full file path
        file_path = os.path.join(directory_path, filename)
        
        # Check if the file is a PDF
        if os.path.isfile(file_path) and filename.lower().endswith('.pdf'):
            # Process the PDF file
            print(file_path)
            bibtex_str = process_header(file_path)
            bibtex_json = bibtex_to_json(bibtex_str, filename)
            if 'doi' in bibtex_json:
                citation = cross_ref(bibtex_json['doi'])
                print(f"{citation=}")
                if 'title' in bibtex_json and 'title' in citation:
                    score = similarity_score(citation['title'], bibtex_json['title'])
                    bibtex_json['score'] = score
                    if score > 0.9:
                        bibtex_json['title'] = citation.get('title','')
                        bibtex_json['author'] = citation.get('authors','')
                        bibtex_json['journal'] = citation.get('journal','')
                        bibtex_json['volume'] = citation.get('volume','')
                        bibtex_json['pages'] = citation.get('page','')
                        bibtex_json['year'] = citation.get('year','')
                elif not 'title' in bibtex_json and 'title' in citation:
                    # If we dont have a title but we do have a doi
                    # Check if the url and the doi are similar
                    # If they are then assume we have a match
                    print("No title but we do have a doi")
                    bibtex_doi = bibtex_json['doi']
                    bibtex_url = bibtex_json['pdf_url']
                    doi_six = bibtex_doi[-6:]
                    if len(bibtex_url) > 4:
                        url_six = bibtex_url[:-4]
                    else:
                        url_six = ''
                    url_six = url_six[-6:]
                    score = similarity_score(doi_six, url_six)
                    if score > 0.9:
                        print("Found a match for no title!!")
                        bibtex_json['title'] = citation.get('title','')
                        bibtex_json['author'] = citation.get('authors','')
                        bibtex_json['journal'] = citation.get('journal','')
                        bibtex_json['volume'] = citation.get('volume','')
                        bibtex_json['pages'] = citation.get('page','')
                        bibtex_json['year'] = citation.get('year','')
                    
            processed +=1
            print(f"{filename} {processed:03d} of {num_files:03d}")
            papers.append(bibtex_json)
            #if processed > 10:
            #    break
            
    return papers

def write_json_to_file(json_data, file_path):
    with open(file_path, 'w') as json_file:
        json.dump(json_data, json_file, indent=2)

# %%
directory_path = '/Users/dan/Code/LLM/research_data/arf_lipid_golgi/'

# Call the function to process PDFs in the directory
papers = process_pdfs_in_directory(directory_path)
#write_json_to_file(papers, "./papers.json")
create_nbib(papers, "arf_lipid_golgi.nbib")
# Out:
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/ijms-23-01073.pdf
# doi found
# citation={'title': 'ER Unfolded Protein Response in Liver In Vivo Is Characterized by Reduced, Not Increased, De Novo Lipogenesis and Cholesterol Synthesis Rates with Uptake of Fatty Acids from Adipose Tissue: Integrated Gene Expression, Translation Rates and Metabolic Fluxes', 'authors': 'Catherine P. Ward and Lucy Peng and Samuel Yuen and Michael Chang and Rozalina Karapetyan and Edna Nyangau and Hussein Mohammed and Hector Palacios and Naveed Ziari and Larry K. Joe and Ashley E. Frakes and Mohamad Dandan and Andrew Dillin and Marc K. Hellerstein', 'journal': 'International Journal of Molecular Sciences', 'year': 2022, 'volume': '23', 'issue': '3', 'page': '1073'}
# 2 titles
# ijms-23-01073.pdf 001 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/PIIS002222752038706X.pdf
# PIIS002222752038706X.pdf 002 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/Su_et_al-2021-Nature_Communications.pdf
# doi found
# citation={'title': 'Structural basis for the ARF GAP activity and specificity of the C9orf72 complex', 'authors': 'Ming-Yuan Su and Simon A. Fromm and Jonathan Remis and Daniel B. Toso and James H. Hurley', 'journal': 'Nature Communications', 'year': 2021, 'volume': '12', 'issue': '1', 'page': 'N/A'}
# 2 titles
# Su_et_al-2021-Nature_Communications.pdf 003 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/41_16005.pdf
# 41_16005.pdf 004 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/scisignal.abm7524.pdf
# scisignal.abm7524.pdf 005 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi
of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/413.pdf
# doi found
# citation={'title': 'Lipid and Carbohydrate Metabolism in Caenorhabditis elegans', 'authors': '', 'journal': 'Genetics', 'year': 2023, 'volume': 'N/A', 'issue': 'N/A', 'page': 'N/A'}
# 2 titles
# 413.pdf 013 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/jcb_202004191.pdf
# doi found
# citation={'title': 'The function of GORASPs in Golgi apparatus organization in vivo', 'authors': 'Rianne Grond and Tineke Veenendaal and Juan M. Duran and Ishier Raote and Johan H. van Es and Sebastiaan Corstjens and Laura Delfgou and Benaissa El Haddouti and Vivek Malhotra and Catherine Rabouille', 'journal': 'Journal of Cell Biology', 'year': 2020, 'volume': '219', 'issue': '9', 'page': 'N/A'}
# No title but we do have a doi
# Found a match for no title!!
# jcb_202004191.pdf 014 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/science.1209038.pdf
# science.1209038.pdf 015 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/s41598-022-05340-6.pdf
# doi found
# citation={'title': 'Cold shock induces a terminal investment reproductive response in C. elegans', 'authors': 'Leah Gulyas and Jennifer R. Powell', 'journal': 'Scientific Reports', 'year': 2022, 'volume': '12', 'issue': '1', 'page': 'N/A'}
# 2 titles
# s41598-022-05340-6.pdf 016 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/1-s2.0-S0167488905000601-main.pdf
# doi found
# citation={'title': 'Lessons from tomographic studies of the mammalian Golgi', 'authors': 'Brad J. Marsh', 'journal': 'Biochimica et Biophysica Acta (BBA) - Molecular Cell Research', 'year': 2005, 'volume': '1744', 'issue': '3', 'page': '273-292'}
# 2 titles
# 1-s2.0-S0167488905000601-main.pdf 017 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/fnins-09-00421.pdf
# doi found
# citation={'title': 'The Golgi complex in stress and death', 'authors': 'Carolyn E. Machamer', 'journal': 'Frontiers in Neuroscience', 'year': 2015, 'volume': '9', 'issue': 'N/A', 'page': 'N/A'}
# 2 titles
# fnins-09-00421.pdf 018 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/d4sm00088a.pdf
# doi found
# citation={'title': 'Preferential electrostatic interactions of phosphatidic acid with arginines', 'authors': 'Nidhin Thomas and Wesley Combs and Kranthi K. Mandadapu and Ashutosh Agrawal', 'journal': 'Soft Matter', 'year': 2024, 'volume': '20', 'issue': '13', 'page': '2998-3006'}
# 2 titles
# d4sm00088a.pdf 019 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/ncb1774.pdf
# doi found
# citation={'title': 'A role for phosphatidic acid in COPI vesicle fission yields insights into Golgi maintenance', 'authors': 'Jia-Shu Yang and Helge Gad and Stella Y. Lee and Alexander Mironov and Leiliang Zhang and Galina V. Beznoussenko and Carmen Valente and Gabriele Turacchio and Akua N. Bonsra and Guangwei Du and Gianluca Baldanzi and Andrea Graziani and Sylvain Bourgoin and Michael A. Frohman and Alberto Luini and Victor W. Hsu', 'journal': 'Nature Cell Biology', 'year': 2008, 'volume': '10', 'issue': '10', 'page': '1146-1153'}
# 2 titles
# ncb1774.pdf 020 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/2023.02.01.526230v1.full.pdf
# doi found
# citation={'title': 'Imaging interorganelle phospholipid transport by extended synaptotagmins using bioorthogonally tagged lipids', 'authors': 'Dongjun Liang and Lin Luan and Jeremy M. Baskin', 'year': 2023, 'volume': 'N/A', 'issue': 'N/A', 'page': 'N/A'}
# 2 titles
# 2023.02.01.526230v1.full.pdf 021 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/chun-et-al-2008-characterization-of-class-i-and-ii-adp-ribosylation-factors-(arfs)-in-live-cells-gdp-bound-class-ii.pdf
# doi found
# Failed to process: 404 Client Error: Not Found for url: https://api.crossref.org/works/10.1091/mbc.E08
# citation={}
# chun-et-al-2008-characterization-of-class-i-and-ii-adp-ribosylation-factors-(arfs)-in-live-cells-gdp-bound-class-ii.pdf 022 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/s41589-024-01575-8.pdf
# s41589-024-01575-8.pdf 023 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/jcb_202102122.pdf
# doi found
# citation={'title': 'mmBCFA C17iso ensures endoplasmic reticulum integrity for lipid droplet growth', 'authors': 'Jingjing Zhang and Ying Hu and Yanli Wang and Lin Fu and Xiumei Xu and Chunxia Li and Jie Xu and Chengbin Li and Linqiang Zhang and Rendan Yang and Xue Jiang and Yingjie Wu and Pingsheng Liu and Xiaoju Zou and Bin Liang', 'journal': 'Journal of Cell Biology', 'year': 2021, 'volume': '220', 'issue': '11', 'page': 'N/A'}
# 2 titles
# jcb_202102122.pdf 024 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/FEBS Letters - 2019 - Sasaki - Golgi stress response and organelle zones.pdf
# doi found
# citation={'title': 'Golgi stress response and organelle zones', 'authors': 'Kanae Sasaki and Hiderou Yoshida', 'journal': 'FEBS Letters', 'year': 2019, 'volume': '593', 'issue': '17', 'page': '2330-2340'}
# 2 titles
# FEBS Letters - 2019 - Sasaki - Golgi stress response and organelle zones.pdf 025 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/nihms543769.pdf
# doi found
# citation={'title': 'Unraveling the Golgi Ribbon', 'authors': 'Jen-Hsuan Wei and Joachim Seemann', 'journal': 'Traffic', 'year': 2010, 'volume': '11', 'issue': '11', 'page': '1391-1400'}
# 2 titles
# nihms543769.pdf 026 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/mvv010.pdf
# doi found
# citation={'title': 'Organelle autoregulation--stress responses in the ER, Golgi, mitochondria and lysosome', 'authors': 'K. Sasaki and H. Yoshida', 'journal': 'Journal of Biochemistry', 'year': 2015, 'volume': '157', 'issue': '4', 'page': '185-195'}
# 2 titles
# mvv010.pdf 027 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/sciadv.adf8966.pdf
# sciadv.adf8966.pdf 028 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/PIIS2211124724006867.pdf
# doi found
# citation={'title': 'Deciphering ER stress-unfolded protein response relationship by visualizing unfolded proteins in the ER', 'authors': 'Fenfen Xu and Likun Wang', 'journal': 'Cell Reports', 'year': 2024, 'volume': '43', 'issue': '6', 'page': '114358'}
# 2 titles
# PIIS2211124724006867.pdf 029 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/li-et-al-2024-ultralow-background-membrane-editors-for-spatiotemporal-control-of-phosphatidic-acid-metabolism-and.pdf
# doi found
# citation={'title': 'Ultralow Background Membrane Editors for Spatiotemporal Control of Phosphatidic Acid Metabolism and Signaling', 'authors': 'Xiang-Ling Li and Reika Tei and Masaaki Uematsu and Jeremy M. Baskin', 'journal': 'ACS Central Science', 'year': 2024, 'volume': '10', 'issue': '3', 'page': '543-554'}
# 2 titles
# li-et-al-2024-ultralow-background-membrane-editors-for-spatiotemporal-control-of-phosphatidic-acid-metabolism-and.pdf 030 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/sciadv.adj4605.pdf
# sciadv.adj4605.pdf 031 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/
of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/A GBF1-Dependent Mechanism for Environmentally Responsive Regulation of ER-Golgi Transport - PMC.pdf
# doi found
# Failed to process: 404 Client Error: Not Found for url: https://api.crossref.org/works/10.1016/j.devcel.2019.04.006:10.1016/j.devcel.2019.04.006
# citation={}
# A GBF1-Dependent Mechanism for Environmentally Responsive Regulation of ER-Golgi Transport - PMC.pdf 061 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/s41556-022-00917-9.pdf
# doi found
# citation={'title': 'METALIC reveals interorganelle lipid flux in live cells by enzymatic mass tagging', 'authors': 'Arun T. John Peter and Carmelina Petrungaro and Matthias Peter and Benoît Kornmann', 'journal': 'Nature Cell Biology', 'year': 2022, 'volume': '24', 'issue': '6', 'page': '996-1004'}
# No title but we do have a doi
# Found a match for no title!!
# s41556-022-00917-9.pdf 062 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/nature04377.pdf
# doi found
# citation={'title': 'Functional genomics reveals genes involved in protein secretion and Golgi organization', 'authors': 'Frederic Bard and Laetitia Casano and Arrate Mallabiabarrena and Erin Wallace and Kota Saito and Hitoshi Kitayama and Gianni Guizzunti and Yue Hu and Franz Wendler and Ramanuj DasGupta and Norbert Perrimon and Vivek Malhotra', 'journal': 'Nature', 'year': 2006, 'volume': '439', 'issue': '7076', 'page': '604-607'}
# 2 titles
# nature04377.pdf 063 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/Hosios_et_al-2022-Nature_Metabolism.pdf
# doi found
# citation={'title': 'mTORC1 regulates a lysosome-dependent adaptive shift in intracellular lipid species', 'authors': 'Aaron M. Hosios and Meghan E. Wilkinson and Molly C. McNamara and Krystle C. Kalafut and Margaret E. Torrence and John M. Asara and Brendan D. Manning', 'journal': 'Nature Metabolism', 'year': 2022, 'volume': '4', 'issue': '12', 'page': '1792-1811'}
# 2 titles
# Hosios_et_al-2022-Nature_Metabolism.pdf 064 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/PIIS096289242030101X.pdf
# doi found
# citation={'title': 'A Novel Paradigm for Expert Core Facility Staff Training', 'authors': 'Jennifer C. Waters', 'journal': 'Trends in Cell Biology', 'year': 2020, 'volume': '30', 'issue': '9', 'page': '669-672'}
# No title but we do have a doi
# PIIS096289242030101X.pdf 065 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/2023.05.17.541061v1.full.pdf
# doi found
# citation={'title': 'Unraveling cellular complexity with unlimited multiplexed super-resolution imaging', 'authors': 'Florian Schueder and Felix Rivera-Molina and Maohan Su and Phylicia Kidd and James E. Rothman and Derek Toomre and Joerg Bewersdorf', 'year': 2023, 'volume': 'N/A', 'issue': 'N/A', 'page': 'N/A'}
# 2 titles
# 2023.05.17.541061v1.full.pdf 066 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/PIIS0021925820699483.pdf
# doi found
# citation={'title': 'Proteomics of Endoplasmic Reticulum-Golgi Intermediate Compartment (ERGIC) Membranes from Brefeldin A-treated HepG2 Cells Identifies ERGIC-32, a New Cycling Protein That Interacts with Human Erv46', 'authors': 'Lionel Breuza and Regula Halbeisen and Paul Jenö and Stefan Otte and Charles Barlowe and Wanjin Hong and Hans-Peter Hauri', 'journal': 'Journal of Biological Chemistry', 'year': 2004, 'volume': '279', 'issue': '45', 'page': '47242-47253'}
# 2 titles
# PIIS0021925820699483.pdf 067 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/Traffic - 2017 - Ignashkova - Cell survival and protein secretion associated with Golgi integrity in response to Golgi.pdf
# doi found
# citation={'title': 'Cell survival and protein secretion associated with Golgi integrity in response to Golgi stress‐inducing agents', 'authors': 'Tatiana I. Ignashkova and Mathieu Gendarme and Katrin Peschk and Hans‐Michael Eggenweiler and Ralph K. Lindemann and Jan H. Reiling', 'journal': 'Traffic', 'year': 2017, 'volume': '18', 'issue': '8', 'page': '530-544'}
# 2 titles
# Traffic - 2017 - Ignashkova - Cell survival and protein secretion associated with Golgi integrity in response to Golgi.pdf 068 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/s41467-022-30060-w.pdf
# doi found
# citation={'title': 'Statin therapy inhibits fatty acid synthase via dynamic protein modifications', 'authors': 'Alec G. Trub and Gregory R. Wagner and Kristin A. Anderson and Scott B. Crown and Guo-Fang Zhang and J. Will Thompson and Olga R. Ilkayeva and Robert D. Stevens and Paul A. Grimsrud and Rhushikesh A. Kulkarni and Donald S. Backos and Jordan L. Meier and Matthew D. Hirschey', 'journal': 'Nature Communications', 'year': 2022, 'volume': '13', 'issue': '1', 'page': 'N/A'}
# 2 titles
# s41467-022-30060-w.pdf 069 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/PIIS002192582300220X.pdf
# doi found
# citation={'title': 'Differential contributions of phosphotransferases CEPT1 and CHPT1 to phosphatidylcholine homeostasis and lipid droplet biogenesis', 'authors': 'Gabriel Dorighello and Michael McPhee and Katie Halliday and Graham Dellaire and Neale D. Ridgway', 'journal': 'Journal of Biological Chemistry', 'year': 2023, 'volume': '299', 'issue': '4', 'page': '104578'}
# 2 titles
# PIIS002192582300220X.pdf 070 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/zhang-et-al-2024-amino-acid-and-protein-specificity-of-protein-fatty-acylation-in-caenorhabditis-elegans.pdf
# doi found
# citation={'title': 'Amino acid and protein specificity of protein fatty acylation in\n            <i>Caenorhabditis elegans</i>', 'authors': 'Bingsen Zhang and Yan Yu and Bennett W. Fox and Yinong Liu and Venkatesh P. Thirumalaikumar and Aleksandra Skirycz and Hening Lin and Frank C. Schroeder', 'journal': 'Proceedings of the National Academy of Sciences', 'year': 2024, 'volume': '121', 'issue': '5', 'page': 'N/A'}
# 2 titles
# zhang-et-al-2024-amino-acid-and-protein-specificity-of-protein-fatty-acylation-in-caenorhabditis-elegans.pdf 071 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/s41556-023-01136-6.pdf
# doi found
# citation={'title': 'Lipid droplets and peroxisomes are co-regulated to drive lifespan extension in response to mono-unsaturated fatty acids', 'authors': 'Katharina Papsdorf and Jason W. Miklas and Amir Hosseini and Matias Cabruja and Christopher S. Morrow and Marzia Savini and Yong Yu and Carlos G. Silva-García and Nicole R. Haseley and Luke Meraz Murphy and Pallas Yao and Elisa de Launoit and Scott J. Dixon and Michael P. Snyder and Meng C. Wang and William B. Mair and Anne Brunet', 'journal': 'Nature Cell Biology', 'year': 2023, 'volume': '25', 'issue': '5', 'page': '672-684'}
# 2 titles
# s41556-023-01136-6.pdf 072 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/s41580-022-00524-4.pdf
# doi found
# citation={'title': 'Regulation of membrane protein structure and function by their lipid nano-environment', 'authors': 'Ilya Levental and Ed Lyman', 'journal': 'Nature Reviews Molecular Cell Biology', 'year': 2022, 'volume': '24', 'issue': '2', 'page': '107-122'}
# No title but we do have a doi
# Found a match for no title!!
# s41580-022-00524-4.pdf 073 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/PIIS1534580724001801.pdf
# doi found
# citation={'title': 'Using an ER-specific optogenetic mechanostimulator to understand the mechanosensitivity of the endoplasmic reticulum', 'authors': 'Yutong Song and Zhihao Zhao and Linyu Xu and Peiyuan Huang and Jiayang Gao and Jingxuan Li and Xuejie Wang and Yiren Zhou and Jinhui Wang and Wenting Zhao and Likun Wang and Chaogu Zheng and Bo Gao and Liwen Jiang and Kai Liu and Yusong Guo and Xiaoqiang Yao and Liting Duan', 'journal': 'Developmental Cell', 'year': 2024, 'volume': '59', 'issue': '11', 'page': '1396-1409.e5'}
# 2 titles
# PIIS1534580724001801.pdf 074 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/PIIS0092867400808351.pdf
# PIIS0092867400808351.pdf 075 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/science.1232578.pdf
# doi found
# citation={'title': 'PINK1-Phosphorylated Mitofusin 2 Is a Parkin Receptor for Culling Damaged Mitochondria', 'authors': 'Yun Chen and Gerald W. Dorn', 'journal': 'Science', 'year': 2013, 'volume': '340', 'issue': '6131', 'page': '471-475'}
# No title but we do have a doi
# science.1232578.pdf 076 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/2022.06.27.497668v1.full.pdf
# doi found
# citation={'title': 'Immuno-electron microscopy localizes <i>Caenorhabditis elegans</i> vitellogenins along the classic exocytosis route', 'authors': 'Chao Zhai and Nan Zhang and Xi-Xia Li and Xue-Ke Tan and Fei Sun and Meng-Qiu Dong', 'year': 2022, 'volume': 'N/A', 'issue': 'N/A', 'page': 'N/A'}
# 2 titles
# 2022.06.27.497668v1.full.pdf 077 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/journal.pbio.3001431.pdf
# doi found
# citation={'title': 'Neuronal HSF-1 coordinates the propagation of fat desaturation across tissues to enable adaptation to high temperatures in C. elegans', 'authors': 'Laetitia Chauve and Francesca Hodge and Sharlene Murdoch and Fatemeh Masoudzadeh and Harry-Jack Mann and Andrea F. Lopez-Clavijo and Hanneke Okkenhaug and Greg West and Bebiana C. Sousa and Anne Segonds-Pichon and Cheryl Li and Steven W. Wingett and Hermine Kienberger and Karin Kleigrewe and Mario de Bono and Michael J. O. Wakelam and Olivia Casanueva', 'journal': 'PLOS Biology', 'year': 2021, 'volume': '19', 'issue': '11', 'page': 'e3001431'}
# 2 titles
# journal.pbio.3001431.pdf 078 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/2024.05.20.594820v1.full.pdf
# doi found
# citation={'title': 'Germline status and micronutrient availability regulate a somatic mitochondrial quality control pathway via short-chain fatty acid metabolism', 'authors': 'James P Held and Nadir H Dbouk and Adrianna M Strozak and Lantana K Grub and Hayeon Ryou and Samantha H Schaffner and Maulik R Patel', 'year': 2024, 'volume': 'N/A', 'issue': 'N/A', 'page': 'N/A'}
# 2 titles
# 2024.05.20.594820v1.full.pdf 079 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/PIIS0022227520315236.pdf
# PIIS0022227520315236.pdf 080 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/1-s2.0-S1534580724000728-main.pdf
# doi found
# citation={'title': 'Navigating the omics era of lipid metabolism', 'authors': 'W. Mike Henne', 'journal': 'Developmental Cell', 'year': 2024, 'volume': '59', 'issue': '5', 'page': '561-565'}
# 2 titles
# 1-s2.0-S1534580724000728-main.pdf 081 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/PII
of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/jcb_202106100.pdf
# doi found
# citation={'title': 'Shared and specific functions of Arfs 1–5 at the Golgi revealed by systematic knockouts', 'authors': 'Mirjam Pennauer and Katarzyna Buczak and Cristina Prescianotto-Baschong and Martin Spiess', 'journal': 'Journal of Cell Biology', 'year': 2021, 'volume': '221', 'issue': '1', 'page': 'N/A'}
# No title but we do have a doi
# Found a match for no title!!
# jcb_202106100.pdf 089 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/41598_2018_Article_35190.pdf
# doi found
# citation={'title': 'GBF1 and Arf1 interact with Miro and regulate mitochondrial positioning within cells', 'authors': 'Laurence Walch and Emilie Pellier and Weihua Leng and Goran Lakisic and Alexis Gautreau and Vincent Contremoulins and Jean-Marc Verbavatz and Catherine L. Jackson', 'journal': 'Scientific Reports', 'year': 2018, 'volume': '8', 'issue': '1', 'page': 'N/A'}
# 2 titles
# 41598_2018_Article_35190.pdf 090 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/sciadv.abj8156.pdf
# sciadv.abj8156.pdf 091 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/pnas.201717877.pdf
# doi found
# citation={'title': 'Golgi stress response reprograms cysteine metabolism to confer cytoprotection in Huntington’s disease', 'authors': 'Juan I. Sbodio and Solomon H. Snyder and Bindu D. Paul', 'journal': 'Proceedings of the National Academy of Sciences', 'year': 2018, 'volume': '115', 'issue': '4', 'page': '780-785'}
# 2 titles
# pnas.201717877.pdf 092 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/s00125-021-05552-x.pdf
# doi found
# citation={'title': 'The CREBRF diabetes-protective rs373863828-A allele is associated with enhanced early insulin release in men of Māori and Pacific ancestry', 'authors': 'Hannah J. Burden and Shannon Adams and Braydon Kulatea and Morag Wright-McNaughton and Danielle Sword and Jennifer J. Ormsbee and Conor Watene-O’Sullivan and Tony R. Merriman and Jennifer L. Knopp and J. Geoffrey Chase and Jeremy D. Krebs and Rosemary M. Hall and Lindsay D. Plank and Rinki Murphy and Peter R. Shepherd and Troy L. Merry', 'journal': 'Diabetologia', 'year': 2021, 'volume': '64', 'issue': '12', 'page': '2779-2789'}
# 2 titles
# s00125-021-05552-x.pdf 093 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/2022.09.15.508072v2.full.pdf
# doi found
# citation={'title': 'A new technology for isolating organellar membranes provides fingerprints of lipid bilayer stress', 'authors': 'John Reinhard and Leonhard Starke and Christian Klose and Per Haberkant and Henrik Hammarén and Frank Stein and Ofir Klein and Charlotte Berhorst and Heike Stumpf and James P. Sáenz and Jochen Hub and Maya Schuldiner and Robert Ernst', 'year': 2022, 'volume': 'N/A', 'issue': 'N/A', 'page': 'N/A'}
# 2 titles
# 2022.09.15.508072v2.full.pdf 094 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/science.abi4708.pdf
# science.abi4708.pdf 095 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/jcs217992.pdf
# doi found
# citation={'title': 'Lipid bilayer stress-activated IRE-1 modulates autophagy during endoplasmic reticulum stress', 'authors': 'Jhee Hong Koh and Lei Wang and Caroline Beaudoin-Chabot and Guillaume Thibault', 'journal': 'Journal of Cell Science', 'year': 2018, 'volume': '131', 'issue': '22', 'page': 'N/A'}
# 2 titles
# jcs217992.pdf 096 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/s41467-021-25398-6.pdf
# doi found
# citation={'title': 'Saturated very long chain fatty acid configures glycosphingolipid for lysosome homeostasis in long-lived C. elegans', 'authors': 'Feng Wang and Yuxi Dai and Xufeng Zhu and Qilong Chen and Huanhu Zhu and Ben Zhou and Haiqing Tang and Shanshan Pang', 'journal': 'Nature Communications', 'year': 2021, 'volume': '12', 'issue': '1', 'page': 'N/A'}
# 2 titles
# s41467-021-25398-6.pdf 097 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi
of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/elife-55745-v2.pdf
# doi found
# citation={'title': 'Lysosome activity is modulated by multiple longevity pathways and is important for lifespan extension in C. elegans', 'authors': 'Yanan Sun and Meijiao Li and Dongfeng Zhao and Xin Li and Chonglin Yang and Xiaochen Wang', 'journal': 'eLife', 'year': 2020, 'volume': '9', 'issue': 'N/A', 'page': 'N/A'}
# 2 titles
# elife-55745-v2.pdf 129 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/2023.08.31.555797v1.full.pdf
# doi found
# citation={'title': 'Anionic phospholipids determine G protein coupling selectivity at distinct subcellular membrane compartments', 'authors': 'Evelyn H. Hernandez and Aashish Manglik and Roshanak Irannejad', 'year': 2023, 'volume': 'N/A', 'issue': 'N/A', 'page': 'N/A'}
# 2 titles
# 2023.08.31.555797v1.full.pdf 130 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/s41467-022-28469-4.pdf
# doi found
# citation={'title': 'Histone H3K4me3 modification is a transgenerational epigenetic signal for lipid metabolism in Caenorhabditis elegans', 'authors': 'Qin-Li Wan and Xiao Meng and Chongyang Wang and Wenyu Dai and Zhenhuan Luo and Zhinan Yin and Zhenyu Ju and Xiaodie Fu and Jing Yang and Qunshan Ye and Zhan-Hui Zhang and Qinghua Zhou', 'journal': 'Nature Communications', 'year': 2022, 'volume': '13', 'issue': '1', 'page': 'N/A'}
# 2 titles
# s41467-022-28469-4.pdf 131 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/duché-sanderson-2024-the-chemical-reactivity-of-membrane-lipids.pdf
# doi found
# citation={'title': 'The Chemical Reactivity of Membrane Lipids', 'authors': 'Genevieve Duché and John M Sanderson', 'journal': 'Chemical Reviews', 'year': 2024, 'volume': '124', 'issue': '6', 'page': '3284-3330'}
# 2 titles
# duché-sanderson-2024-the-chemical-reactivity-of-membrane-lipids.pdf 132 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/PIIS1550413121002230.pdf
# doi found
# citation={'title': 'TMEM41B acts as an ER scramblase required for lipoprotein biogenesis and lipid homeostasis', 'authors': 'Dong Huang and Bolin Xu and Lu Liu and Lingzhi Wu and Yuangang Zhu and Alireza Ghanbarpour and Yawei Wang and Feng-Jung Chen and Jia Lyu and Yating Hu and Yunlu Kang and Wenjing Zhou and Xiao Wang and Wanqiu Ding and Xin Li and Zhaodi Jiang and Jizheng Chen and Xu Zhang and Hongwen Zhou and John Zhong Li and Chunguang Guo and Wen Zheng and Xiuqin Zhang and Peng Li and Thomas Melia and Karin Reinisch and Xiao-Wei Chen', 'journal': 'Cell Metabolism', 'year': 2021, 'volume': '33', 'issue': '8', 'page': '1655-1670.e8'}
# 2 titles
# PIIS1550413121002230.pdf 133 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/zmk3488.pdf
# doi found
# Failed to process: 404 Client Error: Not Found for url: https://api.crossref.org/works/10.1091/mbc.E08
# citation={}
# zmk3488.pdf 134 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/42.pdf
# doi found
# citation={'title': 'Golgi stress–induced transcriptional changes mediated by MAPK signaling and three ETS transcription factors regulate MCL1 splicing', 'authors': 'Jan Baumann and Tatiana I. Ignashkova and Sridhar R. Chirasani and Silvia Ramírez-Peinado and Hamed Alborzinia and Mathieu Gendarme and Kyra Kuhnigk and Valentin Kramer and Ralph K. Lindemann and Jan H. Reiling', 'journal': 'Molecular Biology of the Cell', 'year': 2017, 'volume': '29', 'issue': '1', 'page': '42-52'}
# 2 titles
# 42.pdf 135 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi
of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/PIIS0022227523000147.pdf
# doi found
# citation={'title': 'FACS-assisted single-cell lipidome analysis of phosphatidylcholines and sphingomyelins in cells of different lineages', 'authors': 'Sarah E. Hancock and Eileen Ding and Emma Johansson Beves and Todd Mitchell and Nigel Turner', 'journal': 'Journal of Lipid Research', 'year': 2023, 'volume': '64', 'issue': '3', 'page': '100341'}
# 2 titles
# PIIS0022227523000147.pdf 149 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/journal.pgen.1009736.pdf
# doi found
# citation={'title': 'Genes in human obesity loci are causal obesity genes in C. elegans', 'authors': 'Wenfan Ke and Jordan N. Reed and Chenyu Yang and Noel Higgason and Leila Rayyan and Carolina Wählby and Anne E. Carpenter and Mete Civelek and Eyleen J. O’Rourke', 'journal': 'PLOS Genetics', 'year': 2021, 'volume': '17', 'issue': '9', 'page': 'e1009736'}
# 2 titles
# journal.pgen.1009736.pdf 150 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/4543.pdf
# 4543.pdf 151 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/2022.01.26.477847v1.full.pdf
# doi found
# citation={'title': 'The small GTPase Arf1 regulates ATP synthesis and mitochondria homeostasis by modulating fatty acid metabolism', 'authors': 'Ludovic Enkler and Mirjam Pennauer and Viktoria Szentgyörgyi and Cristina Prescianotto-Baschong and Isabelle Riezman and Aneta Wiesyk and Roza Kucharczyk and Martin Spiess and Howard Riezman and Anne Spang', 'year': 2022, 'volume': 'N/A', 'issue': 'N/A', 'page': 'N/A'}
# 2 titles
# 2022.01.26.477847v1.full.pdf 152 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/1-s2.0-S0021925820770584-main.pdf
# doi found
# citation={'title': 'Dependence of Site-2 Protease Cleavage of ATF6 on Prior Site-1 Protease Digestion Is Determined by the Size of the Luminal Domain of ATF6', 'authors': 'Jingshi Shen and Ron Prywes', 'journal': 'Journal of Biological Chemistry', 'year': 2004, 'volume': '279', 'issue': '41', 'page': '43046-43051'}
# 2 titles
# 1-s2.0-S0021925820770584-main.pdf 153 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/iyab093.pdf
# doi found
# citation={'title': 'A genetic titration of membrane composition in <i>Caenorhabditis elegans</i> reveals its importance for multiple cellular and physiological traits', 'authors': 'Ranjan Devkota and Delaney Kaper and Rakesh Bodhicharla and Marcus Henricsson and Jan Borén and Marc Pilon', 'journal': 'Genetics', 'year': 2021, 'volume': '219', 'issue': '1', 'page': 'N/A'}
# 2 titles
# iyab093.pdf 154 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/elife-92900-v1.pdf
# doi found
# citation={'title': 'Spatiotemporal dissection of the Golgi apparatus and the ER-Golgi intermediate compartment in budding yeast', 'authors': 'Takuro Tojima and Yasuyuki Suda and Natsuko Jin and Kazuo Kurokawa and Akihiko Nakano', 'journal': 'eLife', 'year': 2024, 'volume': '13', 'issue': 'N/A', 'page': 'N/A'}
# 2 titles
# elife-92900-v1.pdf 155 of 157
# /Users/dan/Code/LLM/research_data/arf_lipid_golgi/1-s2.0-S0024320512006595-main.pdf
# doi found
# citation={'title': 'Endoplasmic reticulum stress in HepG2 cells inhibits apolipoprotein A-I secretion', 'authors': 'Emad Naem and Michael J. Haas and Norman C.W. Wong and Arshag D. Mooradian', 'journal': 'Life Sciences', 'year': 2012, 'volume': '92', 'issue': '1', 'page': '72-80'}
# 2 titles
# 1-s2.0-S0024320512006595-main.pdf 156 of 157
